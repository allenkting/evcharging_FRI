# %% [markdown]
# # Main Project Notebook

# %%
import pandas as pd

locations = pd.read_csv('station_locations.csv')
locations = locations[locations['State'] == 'NY']
locations
# Out:
# C:\Users\allen\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (20,33,39,40,41,43,49,55,57,58,62) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       Fuel Type Code                               Station Name  \
# 34675            CNG  Clean Energy - Greenpoint - National Grid
# 34676            CNG    Clean Energy - Canarsie - National Grid
# 34677            CNG      Con Edison - W 29th St Service Center
# 34678            CNG      Con Edison - E 16th St Service Center
# 34679            CNG       Con Edison - Van Nest Service Center
# ...              ...                                        ...
# 37171           ELEC                             1741 RT 9 EV 2
# 37172           ELEC                             1741 RT 9 EV 4
# 37173           ELEC                             1741 RT 9 EV 3
# ...

# %%
from mpl_toolkits.basemap import Basemap 
import matplotlib.pyplot as plt  
import numpy as np
